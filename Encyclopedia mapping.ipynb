# %%
import pandas as pd
import json
df = pd.read_html('https://en.wikipedia.org/wiki/1946_Indian_provincial_elections', header=0)[7]
fortune_500 = json.loads(df.to_json(orient="records"))
df
# Out:
#                         Province  Congress  Muslim League  \
# 0                          Assam        58             31
# 1                         Bengal        86            113
# 2                          Bihar        98             34
# 3                         Bombay       125             30
# 4              Central Provinces        92             13
# 5                         Madras       163             28
# 6   North West Frontier Province        30             17
# 7                         Orissa        47              4
# 8                         Punjab        51             73
# 9                           Sind        18             27
# 10              United Provinces       153             54
# 11                         Total       923            425
#
#                                         Other parties  Independents  Total
# 0                                Europeans 9 Others 3             7    108
# ...

# %%
df.to_csv("muslim.csv")

# %%
import pandas as pd
import json
df = pd.read_html('https://en.wikipedia.org/wiki/1946_Indian_provincial_elections', header=0)[8]
fortune_500 = json.loads(df.to_json(orient="records"))
df
# Out:
#                         Province  Muslim Seats  Muslim League  \
# 0                          Assam            34             31
# 1                         Bengal           119            113
# 2                          Bihar            40             34
# 3                         Bombay            30             30
# 4              Central Provinces            14             13
# 5                         Madras            29             29
# 6   North West Frontier Province            36             17
# 7                         Orissa             4              4
# 8                         Punjab            86             74
# 9                           Sind            34             28
# 10              United Provinces            66             54
# 11                         Total           492            429
#
#    % Of Muslim Seats won by Muslim League
# 0                                     91%
# 1                                     95%
# ...

# %%
df.to_csv("muslimseats.csv")
